# %%
import numpy as np

# %%
# Initial Setup
import sys
sys.path.append('../src')

import setup

# %%
pwd
# Out:
# '/Users/ayushyapare/Desktop/Ayushyas_Life/Work/Learning/DS_ML_LearningPath/Projects/Project_Customer_Segmentation/notebooks'

# %%
# Data Retrieval
from data import download_data
df = download_data('../data/raw/telecom_users.csv')

# %%
df.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1869  7010-BRBUU    Male              0     Yes        Yes      72
# 4528  9688-YGXVR  Female              0      No         No      44
# 6344  9286-DOJGF  Female              1     Yes         No      38
# 6739  6994-KERXL    Male              0      No         No       4
# 432   2181-UAESM    Male              0      No         No       2
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1869          Yes           Yes              No  No internet service  ...
# 4528          Yes            No     Fiber optic                   No  ...
# 6344          Yes           Yes     Fiber optic                   No  ...
# 6739          Yes            No             DSL                   No  ...
# 432           Yes            No             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1869  No internet service  No internet service  No internet service
# 4528                  Yes                   No                  Yes
# 6344                   No                   No                   No
# 6739                   No                   No                   No
# 432                   Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1869  No internet service        Two year               No
# 4528                   No  Month-to-month              Yes
# 6344                   No  Month-to-month              Yes
# 6739                  Yes  Month-to-month              Yes
# 432                    No  Month-to-month               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 1869    Credit card (automatic)          24.10       1734.65    No
# 4528    Credit card (automatic)          88.15        3973.2    No
# 6344  Bank transfer (automatic)          74.95       2869.85   Yes
# 6739           Electronic check          55.90         238.5    No
# 432            Electronic check          53.45         119.5    No
#
# [5 rows x 21 columns]

# %%
# Data Preprocessing
from dataframe_preprocess import preprocess_data, save_data
df = preprocess_data(df)
save_data(df, '../data/processed/telecom_users.csv')

# %%
# Data Exploration

from analyze_data import analyze_dataframe

analyze_dataframe(df)
# Out:
# The first column is not the index, it is: gender
#
# 24 duplicate rows found.
# Duplicates removed.
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5962 entries, 1869 to 860
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            5962 non-null   object
#  1   SeniorCitizen     5962 non-null   int64
#  2   Married           5962 non-null   object
#  3   Children          5962 non-null   object
#  4   tenure            5962 non-null   int64
#  5   PhoneService      5962 non-null   object
#  6   MultipleLines     5962 non-null   object
#  7   InternetService   5962 non-null   object
#  8   OnlineSecurity    5962 non-null   object
#  9   OnlineBackup      5962 non-null   object
#  10  DeviceProtection  5962 non-null   object
#  11  TechSupport       5962 non-null   object
#  12  StreamingTV       5962 non-null   object
#  13  StreamingMovies   5962 non-null   object
#  14  Contract          5962 non-null   object
#  15  PaymentMethod     5962 non-null   object
#  16  MonthlyCharges    5962 non-null   float64
#  17  TotalCharges      5962 non-null   float64
#  18  Churn             5962 non-null   object
# dtypes: float64(2), int64(2), object(15)
# memory usage: 931.6+ KB
#
# Columns and their Data Types:
# gender               object
# SeniorCitizen         int64
# Married              object
# Children             object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object
#
# Unique values in each column:
# gender: 2 unique values
# SeniorCitizen: 2 unique values
# Married: 2 unique values
# Children: 2 unique values
# tenure: 73 unique values
# PhoneService: 2 unique values
# MultipleLines: 2 unique values
# InternetService: 3 unique values
# OnlineSecurity: 2 unique values
# OnlineBackup: 2 unique values
# DeviceProtection: 2 unique values
# TechSupport: 2 unique values
# StreamingTV: 2 unique values
# StreamingMovies: 2 unique values
# Contract: 3 unique values
# PaymentMethod: 4 unique values
# MonthlyCharges: 1526 unique values
# TotalCharges: 5611 unique values
# Churn: 2 unique values
#
# No null values in DataFrame.
#
# Statistics for the dataset:
# --------------------Gender-------------------------
#         total   percent
# gender
# Male     3033  0.508722
# Female   2929  0.491278
# --------------------Married-------------------------
#          total   percent
# Married
# No        3058  0.512915
# Yes       2904  0.487085
# --------------------Children-------------------------
#           total   percent
# Children
# No         4171  0.699597
# Yes        1791  0.300403
# --------------------Phoneservice-------------------------
#               total  percent
# PhoneService
# Yes            5372  0.90104
# No              590  0.09896
# --------------------Multiplelines-------------------------
#                total   percent
# MultipleLines
# No              3414  0.572627
# Yes             2548  0.427373
# --------------------Internetservice-------------------------
#                  total   percent
# InternetService
# Fiber optic       2622  0.439785
# DSL               2065  0.346360
# No                1275  0.213854
# --------------------Onlinesecurity-------------------------
#                 total  percent
# OnlineSecurity
# No               4249  0.71268
# Yes              1713  0.28732
# --------------------Onlinebackup-------------------------
#               total   percent
# OnlineBackup
# No             3872  0.649446
# Yes            2090  0.350554
# --------------------Deviceprotection-------------------------
#                   total   percent
# DeviceProtection
# No                 3907  0.655317
# Yes                2055  0.344683
# --------------------Techsupport-------------------------
#              total  percent
# TechSupport
# No            4227  0.70899
# Yes           1735  0.29101
# --------------------Streamingtv-------------------------
#              total   percent
# StreamingTV
# No            3656  0.613217
# Yes           2306  0.386783
# --------------------Streamingmovies-------------------------
#                  total   percent
# StreamingMovies
# No                3623  0.607682
# Yes               2339  0.392318
# --------------------Contract-------------------------
#                 total   percent
# Contract
# Month-to-month   3245  0.544280
# Two year         1441  0.241697
# One year         1276  0.214022
# --------------------Paymentmethod-------------------------
#                            total   percent
# PaymentMethod
# Electronic check            2001  0.335626
# Mailed check                1350  0.226434
# Bank transfer (automatic)   1308  0.219389
# Credit card (automatic)     1303  0.218551
# --------------------Churn-------------------------
#        total   percent
# Churn
# No      4388  0.735995
# Yes     1574  0.264005
# --------------------Numerical features -------------------------

# %%
# Modeling
from model import fit_kmeans, silhuette_score
cluster_errors = []
for n_clusters in range(2, 11):
    wcsse = fit_kmeans(n_clusters, df)
    cluster_errors.append(wcsse)

silhuette_s = silhuette_score(n_clusters, df)
from evaluate import plot_elbow, plot_silhouette
plot_elbow(cluster_errors)
plot_silhouette(silhuette_s)
#print(silhuette_s)
# Out:
# For n_clusters = 2, The average silhouette_score is : 0.2228
# For n_clusters = 3, The average silhouette_score is : 0.1677
# For n_clusters = 4, The average silhouette_score is : 0.1722
# For n_clusters = 5, The average silhouette_score is : 0.1497
# For n_clusters = 6, The average silhouette_score is : 0.1508
# For n_clusters = 7, The average silhouette_score is : 0.145
# For n_clusters = 8, The average silhouette_score is : 0.1431
# For n_clusters = 9, The average silhouette_score is : 0.1306
# For n_clusters = 10, The average silhouette_score is : 0.1279

# %%
# Modelling and prediction
#from data import preprocess
from sklearn.metrics import classification_report
from pycaret.classification import *
from sklearn.metrics import f1_score
from model import train_and_evaluate_model
import pickle


# Assuming df is already loaded
#X, y = define_features_labels(df)
#X_train, X_test, y_train, y_test = perform_train_test_split(X, y)

# Assuming 'df' is your DataFrame containing the data
fitted_and_tuned_model, X_test, y_test = train_and_evaluate_model(df)

# Make predictions using the tuned model
plot_model(fitted_and_tuned_model,plot='confusion_matrix')

# Save the model to a file
with open('model.pkl', 'wb') as model_file:
    pickle.dump(fitted_and_tuned_model, model_file)

# Save the feature names
feature_names = X_test.columns.tolist()
with open('feature_names.pkl', 'wb') as f:
    pickle.dump(feature_names, f)
# Out:
# <style type="text/css">
# #T_12d26_row10_col1, #T_12d26_row16_col1, #T_12d26_row18_col1, #T_12d26_row20_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_12d26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12d26_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_12d26_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12d26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12d26_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_12d26_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12d26_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_12d26_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12d26_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_12d26_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12d26_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_12d26_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12d26_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_12d26_row4_col1" class="data row4 col1" >(4769, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12d26_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_12d26_row5_col1" class="data row5 col1" >(6367, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_12d26_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_12d26_row6_col1" class="data row6 col1" >(4936, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_12d26_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_12d26_row7_col1" class="data row7 col1" >(1431, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_12d26_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_12d26_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_12d26_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_12d26_row9_col1" class="data row9 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_12d26_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_12d26_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_12d26_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_12d26_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_12d26_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_12d26_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_12d26_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_12d26_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_12d26_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_12d26_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_12d26_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_12d26_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_12d26_row16_col0" class="data row16 col0" >Fix imbalance</td>
#       <td id="T_12d26_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_12d26_row17_col0" class="data row17 col0" >Fix imbalance method</td>
#       <td id="T_12d26_row17_col1" class="data row17 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_12d26_row18_col0" class="data row18 col0" >Transformation</td>
#       <td id="T_12d26_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_12d26_row19_col0" class="data row19 col0" >Transformation method</td>
#       <td id="T_12d26_row19_col1" class="data row19 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_12d26_row20_col0" class="data row20 col0" >Normalize</td>
#       <td id="T_12d26_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_12d26_row21_col0" class="data row21 col0" >Normalize method</td>
#       <td id="T_12d26_row21_col1" class="data row21 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_12d26_row22_col0" class="data row22 col0" >Fold Generator</td>
#       <td id="T_12d26_row22_col1" class="data row22 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_12d26_row23_col0" class="data row23 col0" >Fold Number</td>
#       <td id="T_12d26_row23_col1" class="data row23 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_12d26_row24_col0" class="data row24 col0" >CPU Jobs</td>
#       <td id="T_12d26_row24_col1" class="data row24 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_12d26_row25_col0" class="data row25 col0" >Use GPU</td>
#       <td id="T_12d26_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_12d26_row26_col0" class="data row26 col0" >Log Experiment</td>
#       <td id="T_12d26_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_12d26_row27_col0" class="data row27 col0" >Experiment Name</td>
#       <td id="T_12d26_row27_col1" class="data row27 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_12d26_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_12d26_row28_col0" class="data row28 col0" >USI</td>
#       <td id="T_12d26_row28_col1" class="data row28 col1" >9776</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1c8a3 th {
#   text-align: left;
# }
# #T_1c8a3_row0_col0, #T_1c8a3_row0_col2, #T_1c8a3_row0_col4, #T_1c8a3_row0_col6, #T_1c8a3_row0_col7, #T_1c8a3_row1_col0, #T_1c8a3_row1_col1, #T_1c8a3_row1_col3, #T_1c8a3_row1_col4, #T_1c8a3_row1_col5, #T_1c8a3_row1_col6, #T_1c8a3_row1_col7, #T_1c8a3_row2_col0, #T_1c8a3_row2_col1, #T_1c8a3_row2_col2, #T_1c8a3_row2_col3, #T_1c8a3_row2_col5, #T_1c8a3_row3_col0, #T_1c8a3_row3_col1, #T_1c8a3_row3_col2, #T_1c8a3_row3_col3, #T_1c8a3_row3_col4, #T_1c8a3_row3_col5, #T_1c8a3_row3_col6, #T_1c8a3_row3_col7, #T_1c8a3_row4_col0, #T_1c8a3_row4_col1, #T_1c8a3_row4_col2, #T_1c8a3_row4_col3, #T_1c8a3_row4_col4, #T_1c8a3_row4_col5, #T_1c8a3_row4_col6, #T_1c8a3_row4_col7, #T_1c8a3_row5_col0, #T_1c8a3_row5_col1, #T_1c8a3_row5_col2, #T_1c8a3_row5_col3, #T_1c8a3_row5_col4, #T_1c8a3_row5_col5, #T_1c8a3_row5_col6, #T_1c8a3_row5_col7, #T_1c8a3_row6_col0, #T_1c8a3_row6_col1, #T_1c8a3_row6_col2, #T_1c8a3_row6_col3, #T_1c8a3_row6_col4, #T_1c8a3_row6_col5, #T_1c8a3_row6_col6, #T_1c8a3_row6_col7, #T_1c8a3_row7_col0, #T_1c8a3_row7_col1, #T_1c8a3_row7_col2, #T_1c8a3_row7_col3, #T_1c8a3_row7_col4, #T_1c8a3_row7_col5, #T_1c8a3_row7_col6, #T_1c8a3_row7_col7, #T_1c8a3_row8_col0, #T_1c8a3_row8_col1, #T_1c8a3_row8_col2, #T_1c8a3_row8_col3, #T_1c8a3_row8_col4, #T_1c8a3_row8_col5, #T_1c8a3_row8_col6, #T_1c8a3_row8_col7, #T_1c8a3_row9_col0, #T_1c8a3_row9_col1, #T_1c8a3_row9_col2, #T_1c8a3_row9_col3, #T_1c8a3_row9_col4, #T_1c8a3_row9_col5, #T_1c8a3_row9_col6, #T_1c8a3_row9_col7, #T_1c8a3_row10_col0, #T_1c8a3_row10_col1, #T_1c8a3_row10_col2, #T_1c8a3_row10_col3, #T_1c8a3_row10_col4, #T_1c8a3_row10_col5, #T_1c8a3_row10_col6, #T_1c8a3_row10_col7, #T_1c8a3_row11_col0, #T_1c8a3_row11_col1, #T_1c8a3_row11_col2, #T_1c8a3_row11_col3, #T_1c8a3_row11_col4, #T_1c8a3_row11_col5, #T_1c8a3_row11_col6, #T_1c8a3_row11_col7, #T_1c8a3_row12_col0, #T_1c8a3_row12_col1, #T_1c8a3_row12_col2, #T_1c8a3_row12_col3, #T_1c8a3_row12_col4, #T_1c8a3_row12_col5, #T_1c8a3_row12_col6, #T_1c8a3_row12_col7, #T_1c8a3_row13_col0, #T_1c8a3_row13_col1, #T_1c8a3_row13_col2, #T_1c8a3_row13_col3, #T_1c8a3_row13_col4, #T_1c8a3_row13_col5, #T_1c8a3_row13_col6, #T_1c8a3_row13_col7 {
#   text-align: left;
# }
# #T_1c8a3_row0_col1, #T_1c8a3_row0_col3, #T_1c8a3_row0_col5, #T_1c8a3_row1_col2, #T_1c8a3_row2_col4, #T_1c8a3_row2_col6, #T_1c8a3_row2_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1c8a3_row0_col8, #T_1c8a3_row1_col8, #T_1c8a3_row2_col8, #T_1c8a3_row3_col8, #T_1c8a3_row4_col8, #T_1c8a3_row5_col8, #T_1c8a3_row6_col8, #T_1c8a3_row7_col8, #T_1c8a3_row8_col8, #T_1c8a3_row9_col8, #T_1c8a3_row10_col8, #T_1c8a3_row11_col8, #T_1c8a3_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1c8a3_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1c8a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c8a3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1c8a3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1c8a3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1c8a3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1c8a3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1c8a3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1c8a3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1c8a3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1c8a3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c8a3_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_1c8a3_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1c8a3_row0_col1" class="data row0 col1" >0.8065</td>
#       <td id="T_1c8a3_row0_col2" class="data row0 col2" >0.8494</td>
#       <td id="T_1c8a3_row0_col3" class="data row0 col3" >0.8065</td>
#       <td id="T_1c8a3_row0_col4" class="data row0 col4" >0.8050</td>
#       <td id="T_1c8a3_row0_col5" class="data row0 col5" >0.8056</td>
#       <td id="T_1c8a3_row0_col6" class="data row0 col6" >0.4935</td>
#       <td id="T_1c8a3_row0_col7" class="data row0 col7" >0.4937</td>
#       <td id="T_1c8a3_row0_col8" class="data row0 col8" >0.1580</td>
#     </tr>
#     <tr>
#       <th id="T_1c8a3_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_1c8a3_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_1c8a3_row1_col1" class="data row1 col1" >0.8023</td>
#       <td id="T_1c8a3_row1_col2" class="data row1 col2" >0.8512</td>
#       <td id="T_1c8a3_row1_col3" class="data row1 col3" >0.8023</td>
#       <td id="T_1c8a3_row1_col4" class="data row1 col4" >0.8093</td>
#       <td id="T_1c8a3_row1_col5" class="data row1 col5" >0.8051</td>
#       <td id="T_1c8a3_row1_col6" class="data row1 col6" >0.5027</td>
#       <td id="T_1c8a3_row1_col7" class="data row1 col7" >0.5039</td>
#       <td id="T_1c8a3_row1_col8" class="data row1 col8" >0.6500</td>
#     </tr>
#     <tr>
#       <th id="T_1c8a3_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_1c8a3_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_1c8a3_row2_col1" class="data row2 col1" >0.8008</td>
#       <td id="T_1c8a3_row2_col2" class="data row2 col2" >0.8508</td>
#       <td id="T_1c8a3_row2_col3" class="data row2 col3" >0.8008</td>
#       <td id="T_1c8a3_row2_col4" class="data row2 col4" >0.8101</td>
#       <td id="T_1c8a3_row2_col5" class="data row2 col5" >0.8044</td>
#       <td id="T_1c8a3_row2_col6" class="data row2 col6" >0.5035</td>
#       <td id="T_1c8a3_row2_col7" class="data row2 col7" >0.5054</td>
#       <td id="T_1c8a3_row2_col8" class="data row2 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_1c8a3_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_1c8a3_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_1c8a3_row3_col1" class="data row3 col1" >0.7999</td>
#       <td id="T_1c8a3_row3_col2" class="data row3 col2" >0.8509</td>
#       <td id="T_1c8a3_row3_col3" class="data row3 col3" >0.7999</td>
#       <td id="T_1c8a3_row3_col4" class="data row3 col4" >0.8093</td>
#       <td id="T_1c8a3_row3_col5" class="data row3 col5" >0.8035</td>
#       <td id="T_1c8a3_row3_col6" class="data row3 col6" >0.5014</td>
#       <td id="T_1c8a3_row3_col7" class="data row3 col7" >0.5033</td>
#       <td id="T_1c8a3_row3_col8" class="data row3 col8" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_1c8a3_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_1c8a3_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_1c8a3_row4_col1" class="data row4 col1" >0.7999</td>
#       <td id="T_1c8a3_row4_col2" class="data row4 col2" >0.8435</td>
#       <td id="T_1c8a3_row4_col3" class="data row4 col3" >0.7999</td>
#       <td id="T_1c8a3_row4_col4" class="data row4 col4" >0.8033</td>
#       <td id="T_1c8a3_row4_col5" class="data row4 col5" >0.8014</td>
#       <td id="T_1c8a3_row4_col6" class="data row4 col6" >0.4888</td>
#       <td id="T_1c8a3_row4_col7" class="data row4 col7" >0.4892</td>
#       <td id="T_1c8a3_row4_col8" class="data row4 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_1c8a3_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_1c8a3_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1c8a3_row5_col1" class="data row5 col1" >0.8014</td>
#       <td id="T_1c8a3_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_1c8a3_row5_col3" class="data row5 col3" >0.8014</td>
#       <td id="T_1c8a3_row5_col4" class="data row5 col4" >0.7950</td>
#       <td id="T_1c8a3_row5_col5" class="data row5 col5" >0.7972</td>
#       <td id="T_1c8a3_row5_col6" class="data row5 col6" >0.4643</td>
#       <td id="T_1c8a3_row5_col7" class="data row5 col7" >0.4662</td>
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]
# <style type="text/css">
# #T_71201_row10_col0, #T_71201_row10_col1, #T_71201_row10_col2, #T_71201_row10_col3, #T_71201_row10_col4, #T_71201_row10_col5, #T_71201_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_71201">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71201_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_71201_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_71201_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_71201_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_71201_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_71201_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_71201_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71201_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71201_row0_col0" class="data row0 col0" >0.7904</td>
#       <td id="T_71201_row0_col1" class="data row0 col1" >0.8514</td>
#       <td id="T_71201_row0_col2" class="data row0 col2" >0.7904</td>
#       <td id="T_71201_row0_col3" class="data row0 col3" >0.7822</td>
#       <td id="T_71201_row0_col4" class="data row0 col4" >0.7851</td>
#       <td id="T_71201_row0_col5" class="data row0 col5" >0.4306</td>
#       <td id="T_71201_row0_col6" class="data row0 col6" >0.4326</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71201_row1_col0" class="data row1 col0" >0.7904</td>
#       <td id="T_71201_row1_col1" class="data row1 col1" >0.8356</td>
#       <td id="T_71201_row1_col2" class="data row1 col2" >0.7904</td>
#       <td id="T_71201_row1_col3" class="data row1 col3" >0.8009</td>
#       <td id="T_71201_row1_col4" class="data row1 col4" >0.7946</td>
#       <td id="T_71201_row1_col5" class="data row1 col5" >0.4793</td>
#       <td id="T_71201_row1_col6" class="data row1 col6" >0.4812</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71201_row2_col0" class="data row2 col0" >0.8293</td>
#       <td id="T_71201_row2_col1" class="data row2 col1" >0.8690</td>
#       <td id="T_71201_row2_col2" class="data row2 col2" >0.8293</td>
#       <td id="T_71201_row2_col3" class="data row2 col3" >0.8254</td>
#       <td id="T_71201_row2_col4" class="data row2 col4" >0.8270</td>
#       <td id="T_71201_row2_col5" class="data row2 col5" >0.5452</td>
#       <td id="T_71201_row2_col6" class="data row2 col6" >0.5460</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71201_row3_col0" class="data row3 col0" >0.8084</td>
#       <td id="T_71201_row3_col1" class="data row3 col1" >0.8385</td>
#       <td id="T_71201_row3_col2" class="data row3 col2" >0.8084</td>
#       <td id="T_71201_row3_col3" class="data row3 col3" >0.8044</td>
#       <td id="T_71201_row3_col4" class="data row3 col4" >0.8061</td>
#       <td id="T_71201_row3_col5" class="data row3 col5" >0.4913</td>
#       <td id="T_71201_row3_col6" class="data row3 col6" >0.4918</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71201_row4_col0" class="data row4 col0" >0.8293</td>
#       <td id="T_71201_row4_col1" class="data row4 col1" >0.8856</td>
#       <td id="T_71201_row4_col2" class="data row4 col2" >0.8293</td>
#       <td id="T_71201_row4_col3" class="data row4 col3" >0.8264</td>
#       <td id="T_71201_row4_col4" class="data row4 col4" >0.8277</td>
#       <td id="T_71201_row4_col5" class="data row4 col5" >0.5486</td>
#       <td id="T_71201_row4_col6" class="data row4 col6" >0.5491</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71201_row5_col0" class="data row5 col0" >0.7904</td>
#       <td id="T_71201_row5_col1" class="data row5 col1" >0.8154</td>
#       <td id="T_71201_row5_col2" class="data row5 col2" >0.7904</td>
#       <td id="T_71201_row5_col3" class="data row5 col3" >0.7971</td>
#       <td id="T_71201_row5_col4" class="data row5 col4" >0.7933</td>
#       <td id="T_71201_row5_col5" class="data row5 col5" >0.4717</td>
#       <td id="T_71201_row5_col6" class="data row5 col6" >0.4726</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71201_row6_col0" class="data row6 col0" >0.7904</td>
#       <td id="T_71201_row6_col1" class="data row6 col1" >0.8145</td>
#       <td id="T_71201_row6_col2" class="data row6 col2" >0.7904</td>
#       <td id="T_71201_row6_col3" class="data row6 col3" >0.7904</td>
#       <td id="T_71201_row6_col4" class="data row6 col4" >0.7904</td>
#       <td id="T_71201_row6_col5" class="data row6 col5" >0.4560</td>
#       <td id="T_71201_row6_col6" class="data row6 col6" >0.4560</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71201_row7_col0" class="data row7 col0" >0.8234</td>
#       <td id="T_71201_row7_col1" class="data row7 col1" >0.8714</td>
#       <td id="T_71201_row7_col2" class="data row7 col2" >0.8234</td>
#       <td id="T_71201_row7_col3" class="data row7 col3" >0.8269</td>
#       <td id="T_71201_row7_col4" class="data row7 col4" >0.8249</td>
#       <td id="T_71201_row7_col5" class="data row7 col5" >0.5499</td>
#       <td id="T_71201_row7_col6" class="data row7 col6" >0.5503</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71201_row8_col0" class="data row8 col0" >0.7988</td>
#       <td id="T_71201_row8_col1" class="data row8 col1" >0.8543</td>
#       <td id="T_71201_row8_col2" class="data row8 col2" >0.7988</td>
#       <td id="T_71201_row8_col3" class="data row8 col3" >0.8062</td>
#       <td id="T_71201_row8_col4" class="data row8 col4" >0.8019</td>
#       <td id="T_71201_row8_col5" class="data row8 col5" >0.4956</td>
#       <td id="T_71201_row8_col6" class="data row8 col6" >0.4968</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_71201_row9_col0" class="data row9 col0" >0.7838</td>
#       <td id="T_71201_row9_col1" class="data row9 col1" >0.8058</td>
#       <td id="T_71201_row9_col2" class="data row9 col2" >0.7838</td>
#       <td id="T_71201_row9_col3" class="data row9 col3" >0.7822</td>
#       <td id="T_71201_row9_col4" class="data row9 col4" >0.7830</td>
#       <td id="T_71201_row9_col5" class="data row9 col5" >0.4357</td>
#       <td id="T_71201_row9_col6" class="data row9 col6" >0.4357</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_71201_row10_col0" class="data row10 col0" >0.8035</td>
#       <td id="T_71201_row10_col1" class="data row10 col1" >0.8441</td>
#       <td id="T_71201_row10_col2" class="data row10 col2" >0.8035</td>
#       <td id="T_71201_row10_col3" class="data row10 col3" >0.8042</td>
#       <td id="T_71201_row10_col4" class="data row10 col4" >0.8034</td>
#       <td id="T_71201_row10_col5" class="data row10 col5" >0.4904</td>
#       <td id="T_71201_row10_col6" class="data row10 col6" >0.4912</td>
#     </tr>
#     <tr>
#       <th id="T_71201_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_71201_row11_col0" class="data row11 col0" >0.0169</td>
#       <td id="T_71201_row11_col1" class="data row11 col1" >0.0255</td>
#       <td id="T_71201_row11_col2" class="data row11 col2" >0.0169</td>
#       <td id="T_71201_row11_col3" class="data row11 col3" >0.0164</td>
#       <td id="T_71201_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 25
#      22     pickle.dump(fitted_and_tuned_model, model_file)
#      24 # Save the feature names
# ---> 25 feature_names = X_train.columns.tolist()
#      26 with open('feature_names.pkl', 'wb') as f:
#      27     pickle.dump(feature_names, f)
#
# NameError: name 'X_train' is not defined
